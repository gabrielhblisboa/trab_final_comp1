# %% [markdown]
# # Trabalho Final de Sistemas Lineares I
#
# Nome: Gabriel Henrique Braga Lisboa \\
# DRE: 120095995 \\
# Curso: Engenharia Eletrônica e de Computação \\
# Período: 2022.2 \\
# Universidade Federal do Rio de Janeiro

# %%
import cmath
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.signal import bessel, lsim, lti, impulse, step, freqs, tf2zpk
from numpy.lib import index_tricks
#!pip install control
#from control import pzmap
#colors = ['k', 'g','r','c','m','y','b']

# %% [markdown]
# # Questão 1

# %% [markdown]
# # (A)
#
# # Circuitos 1 e 2
#
# Os circuitos 1 e 2 são filtros passa-faixa. No filtro passa-faixa, também chamado de passa-banda, o ganho é aumentado em toda a banda passante. Portanto, esse filtro permite que as frequências de uma certa faixa passem livremente, enquanto que as frequências fora dessa faixa são atenuadas (reduzidas em amplitude). \\
#
# Uma aplicação comum dos passa-faixa é na filtragem dos dados meteorológico. O filtro em questão trabalha com uma determinada faixa de período de modo que apenas os ciclones permaneçam como flutuações nos campos de dados.
#
# # Circuito 3
#
# O circuito 3 é um filtro passa-baixa. O filtro passa-baixa é um circuito que permite a passagem de sinais de baixa frequência ao mesmo tempo que reduz a intensidade de sinais de alta frequência.
#
# Isto é, a partir de uma frequência de referência, chamada frequência de corte, ele permite que frequências mais baixas que ela passem livremente, e frequências mais altas são atenuadas (reduzidas em amplitude).
#
# Uma aplicação interessante para ele é o seu uso em processamento de imagens, para suavizar a imagem, atenuando as altas frequências, que correspondem às transições abruptas, e assim minimizando ruídos e produzindo maior borramento na imagem.
#
# # Circuito 4
#
# O circuito 4 corresponde a um buffer. Um circuito buffer fornece um meio de isolar o sinal de entrada de uma carga utilizando um estágio de ganho unitário, sem inversão.
#
# Vantagens: \\
# Alta impedância de entrada
# Baixa impedância de saída
#
# # Circuito 5
#
# O circuito 5 é um integrador de tensão, ou seja, um circuito eletrônico que realiza um processo de integração (soma infinitesimal) dos sinais decorrentes da variação do sinal de entrada conforme sua variação no intervalo de tempo analisado.

# %% [markdown]
# # (D) e (E) - EDO's e Funções de Transferência dos Circuitos

# %% [markdown]
# # Circuito 1

# %% [markdown]
# ![Trab Questão 1_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # (F) - Diagrama de Polos e Zeros

# %% [markdown]
# # Circuito 1
#
# Valores dos Componentes: \\
#
# R1 = 10 Ω \\
# R2 = 10 Ω \\
# C = 1 mF \\
# L = 10 mH \\
#
# \\
#
# Polos e Zeros: \\
#
# Zero = 0 \\
# Polos ≈ -100 ± j300

# %%
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

(zeros, poles, gain) = tf2zpk([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])
angle = np.linspace(-np.pi, np.pi, 500)
cirx = np.sin(angle)
ciry = np.cos(angle)

plt.plot(poles.real, poles.imag, 'x', zeros.real, zeros.imag, 'o')
plt.grid()
plt.xlim((-200, 200))
plt.xlabel('Real')
plt.ylim((-500, 500))
plt.ylabel('Imaginário')
plt.figure()

plt.gcf().set_figwidth(1)

# %% [markdown]
# Com os valores dos componentes utilizados, percebe-se que o sistema assintóticamente estável, pois possui ambos os polos imaginários estão no Semi-Plano Lateral Esquerdo (SPLE).

# %% [markdown]
# # Circuito 2
#
# Valores dos Componentes: \\
#
# R1 = 10 Ω \\
# R2 = 100 Ω \\
# C1 = 50 $μ$F \\
# L1 = 100 mH \\
#
# Polos e Zeros: \\
#
# Zero = 0 \\
# Polos ≈ -229,84  e  -870,16

# %%
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

(zeros, poles, gain) = tf2zpk([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])
angle = np.linspace(-np.pi, np.pi, 500)
cirx = np.sin(angle)
ciry = np.cos(angle)

plt.plot(poles.real, poles.imag, 'x', zeros.real, zeros.imag, 'o')
plt.grid()
plt.xlim((-1000, 100))
plt.xlabel('Real')
plt.ylim((-5, 5))
plt.ylabel('Imaginário')
plt.figure()

plt.gcf().set_figwidth(1)

# %% [markdown]
# Esse sistema tambem é assintóticamente estável, pois ambos os polos estão situados no SPLE.

# %% [markdown]
# # Circuito 3
#
# Valores dos Componentes: \\
#
# R1 = 1 KΩ \\
# R2 = 10 KΩ \\
# C1 = 3 $μ$F \\
# C2 = 5 $μ$F \\
#
# Polos e Zeros: \\
#
# Zero ⇒ não existe \\
# Polos ≈ -347,48  e  -19,19

# %%
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

(zeros, poles, gain) = tf2zpk([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])
angle = np.linspace(-np.pi, np.pi, 500)
cirx = np.sin(angle)
ciry = np.cos(angle)

plt.plot(poles.real, poles.imag, 'x', zeros.real, zeros.imag, 'o')
plt.grid()
plt.xlim((-500, 100))
plt.xlabel('Real')
plt.ylim((-10, 10))
plt.ylabel('Imaginário')
plt.figure()

plt.gcf().set_figwidth(1)

# %% [markdown]
# A função de transferência do sistema é assintóticamente estável, pois possui todos os polos situados no SPLE.

# %% [markdown]
# # Circuito 4
#
# Como nesse circuito H(s) = 1, ele não possui nenhum polo ou zero. Portanto, não é necessário fazer um diagrama de polos e zeros nesse caso.

# %% [markdown]
# # Circuito 5
#
# Valores dos Componentes: \\
#
# R1 = 100 Ω \\
# C2 = 5 $μ$F \\
#
# Polos e Zeros: \\
#
# Zero ⇒ não existe \\
# Polos = 0

# %%
R1 = 100
C2 = 5*(10**(-6))

(zeros, poles, gain) = tf2zpk([-1], [C2*R1, 0])
angle = np.linspace(-np.pi, np.pi, 500)
cirx = np.sin(angle)
ciry = np.cos(angle)

plt.plot(poles.real, poles.imag, 'x', zeros.real, zeros.imag, 'o')
plt.grid()
plt.xlim((-5, 5))
plt.xlabel('Real')
plt.ylim((-5, 5))
plt.ylabel('Imaginário')
plt.figure()

plt.gcf().set_figwidth(1)

# %% [markdown]
# Esse sistema é marginalmente estável pois não há polos de multiplicidade maior do que 1 sobre o eixo imaginário e não há nenhum polo no Semi-Plano Lateral Direito (SPLD), há somente um polo de multiplicidade 1 sobre o eixo imaginário.
#
# Obs: independente da escolha de valores de R1 e C2, o diagrama de polos e zeros permanecerá o mesmo.

# %% [markdown]
# # Circuito 6
#
# Valores dos Componentes: \\
#
# R1 = 10 Ω \\
# C2 = 3 $μ$F \\
#
# Polos e Zeros: \\
#
# Zero ⇒ não existe \\
# Polos = 0

# %%
R = 100
C = 5*(10**(-6))

(zeros, poles, gain) = tf2zpk([1], [R*C, 0])
angle = np.linspace(-np.pi, np.pi, 500)
cirx = np.sin(angle)
ciry = np.cos(angle)

plt.plot(poles.real, poles.imag, 'x', zeros.real, zeros.imag, 'o')
plt.grid()
plt.xlim((-5, 5))
plt.xlabel('Real')
plt.ylim((-5, 5))
plt.ylabel('Imaginário')
plt.figure()

plt.gcf().set_figwidth(1)

# %% [markdown]
# De novo, o sistema é marginalmente estável, pois há um polo de multiplicidade 1 sobre o eixo imaginário, e não há polos no SPLD.
#
# Nesse caso, acontece o mesmo que no circuito 5: o diagrama permanece o mesmo independentemente dos valores de R e C.

# %% [markdown]
# # (G) - Diagrama de Bode

# %% [markdown]
# # Circuito 1

# %%
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

sys1 = signal.TransferFunction([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys1,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r') # Bode magnitude plot
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r') # Bode phase plot
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# Esse gráfico é o esperado para um filtro passa-faixa, pois amplifica uma determinada faixa de frequência e atenua as frequências menores ou maiores do que essa banda. As frequências de banda estão dentro de um intervalo aproximado de 100 rad/s e 1000 rad/s. \\
#
# A fase varia entre 90º e -90º, o que corresponde à diferença de fase quando o filtro atua como passa-alta e como passa-baixa
#
# Como a função de transferência desse circuito tem um polo de segunda ordem, há um coeficiente de amortecimento.

# %% [markdown]
# # Circuito 2

# %%
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

sys2 = signal.TransferFunction([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys2,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r')
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r')
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# Por ser também um filtro passa-faixa passivo, esse gráfico é semelhante ao do circuito 1. Também amplifica uma determinada faixa de frequência e atenua as frequências menores ou maiores do que essa banda. Nesse caso, as frequências de banda estão dentro de um intervalo aproximado de 300 rad/s e 3000 rad/s. \\
#
# Uma diferença deste gráfico em ralação ao circuito 1, é que o intervalo de banda é maior.
#
# A fase varia entre 90º e -90º, o que corresponde à diferença de fase quando o filtro atua como passa-alta e como passa-baixa
#
# Como a função de transferência desse circuito tem um polo de segunda ordem, há um coeficiente de amortecimento.

# %% [markdown]
# # Circuito 3

# %%
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

sys3 = signal.TransferFunction([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys3,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r')
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r')
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")
plt.tight_layout()
plt.show()

# %% [markdown]
# Esse gráfico é o equivalente à um passa-baixa, o que está de acordo com o que foi discutido na letra (a) da Questão 1. Percebe-se que esse tipo de filtro atenua as frequências maiores do que a frequência de corte.
#
# Pelo diagrama, podemos estimar que a frequência de corte é de 10 rad/s.

# %% [markdown]
# # Circuito 4

# %%
sys4 = signal.TransferFunction([1],[1])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys4,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r')
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r')
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# Como esperado por ter uma função de transferência igual à 1, o diagrama de Bode do circuito 4 é uma reta horizontal em 0, tanto para a amplitude quanto para a fase. A resposta do sistema será igual ao sinal de entrada.

# %% [markdown]
# # Circuito 5

# %%
R1 = 100
C2 = 5*(10**(-6))

sys5 = signal.TransferFunction([-1], [C2*R1, 0])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys5,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r')
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r')
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# Esse diagrama de Bode possui o formato esperado para um integrador inversor, e atenua as frequências proporcionalmente ao crescimento delas.
#
# Sua fase é constante em 90°.

# %% [markdown]
# # Circuito 6

# %%
R = 100
C = 5*(10**(-6))

sys6 = signal.TransferFunction([1], [R*C, 0])

w = np.logspace(-2,5,num=100, base=10.0)
w, mag, phase = signal.bode(sys6,w=w,n=200)

fig, graph = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex=False)

graph[0].set_title('Diagrama de Bode (Amplitude+Fase)')
graph[0].semilogx(w,mag, label='Magnitude', color='r')
graph[0].set_ylabel('Amplitude(dB)')
graph[0].grid(True, which="both", ls="-")

graph[1].semilogx(w,phase, label='Phase', color='r')
graph[1].set_ylabel('Fase(graus)')
graph[1].set_xlabel('$\omega$(rad/s)')
graph[1].grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# Percebe-se que o gráfico desse circuito é idêntico ao diagrama de Bode do circuito 5, pois também é um integrador. Como dito no item anterior, independentemente dos valores dos componentes desses dois circuitos, os polos e zeros continuarão os mesmos.

# %% [markdown]
# # (H) - Resposta ao Degrau Unitário

# %% [markdown]
# # Circuito 1

# %%
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 0.1,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 1

#Definição da função de transferência
sys1 = signal.TransferFunction([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])
tout, yout = signal.step(sys1, T=t)
          
plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Nas fases constantes do degrau unitário, ele é um sinal de frequência muito baixa, e na fase de subida ele é um sinal de frequência muito alta. Como o circuito é um passa-faixa, essas frequências fora da banda serão atenuadas muito rapidamente.
#
# Como há um polo de segunda ordem na função de transferência desse cirucito, há um coeficiente de amortecimento, que provoca um amortecimento subcrítico, formando essa curva senóide de amplitude decrescente.
#
# Obs: Dentro da banda ideal de frequência ainda existe um ganho, como analisado no diagrama de Bode

# %% [markdown]
# # Circuito 2

# %%
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 0.03,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 1

#Definição da função de transferência
sys2 = signal.TransferFunction([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])
tout, yout = signal.step(sys2, T=t)
          
plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Nesse circuito passa-faixa, pode-se notar que o pico do sinal não alcança a amplitude de entrada do degrau unitário, pois as frequências muito baixas e muito altas são atenuadas muito rapidamente, e dentro da banda ideal de frequência ainda existe um ganho, como analisado no Diagrama de Bode.

# %% [markdown]
# # Circuito 3

# %%
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 1,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 1

#Definição da função de transferência
sys3 = signal.TransferFunction([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])
tout, yout = signal.step(sys3, T=t)
          
plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# É possível observar que, na resposta do sistema ao degrau unitário, existe um ganho no início da subida da amplitude do sinal de resposta em relação ao degrau da entrada. Isso ocorre devido a atuação do circuito como filtro passa-baixa, que atenua a onda que é extremamente vertical, ou seja, de altíssima frequência, e acaba gerando essa curva no sinal de saída. Depois disso, a resposta fica estabilizada horizontalmente, já que a frequência diminiu e o filtro para de atenuar a amplitude das ondas.

# %% [markdown]
# # Circuito 4

# %%
#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 0.3,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 0.99

#Definição da função de transferência
sys4 = signal.TransferFunction([1], [1])
tout, yout = signal.step(sys4, T=t)
          
plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 5

# %%
R1 = 100
C2 = 5*(10**(-6))

#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 0.01,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 1

#Definição da função de transferência
sys5 = signal.TransferFunction([-1], [C2*R1, 0])
tout, yout = signal.step(sys5, T=t)


plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# A resposta é uma rampa unitária inversa.

# %% [markdown]
# # Circuito 6

# %%
R = 100
C = 5*(10**(-6))

#Definindo a variável de tempo, dos coeficientes de alfa e do degrau unitário
t=np.linspace(0, 0.01,1000,endpoint=False)
input=np.zeros_like(t)
input[t>0.0] = 1

#Definição da função de transferência
sys6 = signal.TransferFunction([1], [R*C, 0])
tout, yout = signal.step(sys6, T=t)


plt.plot(t,input,'k',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout, yout, "r", linewidth=1.5, label='Saída')
plt.legend(loc='best',shadow=True,framealpha=1)
plt.grid(alpha=0.5)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Como o circuito 6 é um integrador não inversor, a resposta é uma rampa unitária.

# %% [markdown]
# # (I) - Resposta à Rampa Unitária

# %% [markdown]
# # Circuito 1

# %%
from scipy.fft import fft
from scipy.fftpack import fftfreq

# %%
nfft = u.shape[0]
# u = np.sin(t)/t
# u[t == 0] = 1
freqs = fftfreq(nfft)
xax = list(range(freqs.shape[0]))
spec = fft(u, nfft)
suu = np.abs(spec)
plt.plot(xax, suu)
ax = plt.gca()
ax.set_xticklabels(freqs, rotation=45)
# Out:
# [Text(0, 0, '0.0'),
#  Text(0, 0, '0.001'),
#  Text(0, 0, '0.002'),
#  Text(0, 0, '0.003'),
#  Text(0, 0, '0.004'),
#  Text(0, 0, '0.005'),
#  Text(0, 0, '0.006'),
#  Text(0, 0, '0.007')]

# %%
# Valores dos Componentes
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

t=np.linspace(0,0.03,1000,endpoint=False)
u=t

sys1 = lti([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])
tout, yout, xout = lsim(sys1,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# O espectro de Fourier da rampa unitária nos mostra que a maior parte daa intensidade do sinal está concentrada em frequências mais baixas. Portanto, o filtro passa-faixa atenua a maior parte do sinal de entrada, ocasionando apenas uma pequena subida inicial. Conforme a frequência vai aumentando à longo prazo, a resposta tende a se estabilizar.

# %% [markdown]
# # Circuito 2

# %%
# Valores dos Componentes
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

t=np.linspace(0,0.01,1000,endpoint=False)
u=t

sys2 = lti([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])
tout, yout, xout = lsim(sys2,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Novamente, o filtro passa-banda começa a atenuar a frequência inicial da banda, gerando uma pequena subida inicial. No longo prazo, a resposta tende a estabilizar, após inicialmente sofrer essa subida.

# %% [markdown]
# # Circuito 3

# %%
# Valores dos Componentes
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

t=np.linspace(0,0.1,1000,endpoint=False)
u=t

sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])
tout, yout, xout = lsim(sys3,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# Se utilizarmos uma escala de tempo maior, as curvas irão coincidir

t=np.linspace(0,5,1000,endpoint=False)
u=t

sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])
tout, yout, xout = lsim(sys3,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Como a magnitude do sinal de entrada está concentrada nas frequências mais baixas, um filtro passa-baixa irá deixar passar a maior parte do sinal, providenciando como resposta do sistema uma outra rampa de inclinação semelhante, que tende a convergir com a rampa unitária da entrada.
#
# O único detalhe aqui é que, bem no início do sinal, a onda é levemente atenuada, por causa da verticalização da entrada e da atuação do passa-baixa. A partir do momento que a onda se estabiliza, a resposta segue uma rampa com a mesma inclinação da entrada, mas com um atraso, ainda que bem pequeno.

# %% [markdown]
# # Circuito 4

# %%
t=np.linspace(0,0.1,1000,endpoint=False)
u=t

sys4 = lti([1], [1])
tout, yout, xout = lsim(sys4,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 5

# %%
# Valores dos Componentes
R1 = 100
C2 = 5*(10**(-6))

t=np.linspace(0,0.01,1000,endpoint=False)
u=t

sys5 = lti([-1], [C2*R1, 0])
tout, yout, xout = lsim(sys5,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# A resposta a rampa unitária é uma parábola decrescente. Tendo em vista que o circuito é um integrador inversor, e a função de entrada da rampa é "t", é natural que a resposta seja o inverso da sua integral, $-\frac{s^2}{2}$

# %% [markdown]
# # Circuito 6

# %%
# Valores dos Componentes
R = 100
C = 5*(10**(-6))

t=np.linspace(0,0.01,1000,endpoint=False)
u=t

sys5 = lti([1], [R*C, 0])
tout, yout, xout = lsim(sys5,U=u,T=t)

plt.plot(t,u,'r',alpha=0.5,linewidth=1.5,label='Entrada')
plt.plot(tout,yout,'k',linewidth=1.5,label='Saída')
plt.legend(loc='upper left',shadow=True,framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Como este circuito é um integrador não inversor, era esperado que a resposta fosse o inverso da resposta do circuito 5, $\frac{s^2}{2}$

# %% [markdown]
# # (J) - Resposta a uma onda quadrada de frequência ω

# %% [markdown]
# # Circuito 1

# %%
#Foi escolhido uma frequência w de 100
w = 100

R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

#Função de transferência
sys1 = signal.lti([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])


#Definição da variável tempo e da onda quadrada
t = np.linspace(0, 0.5, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys1, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# Ampliado é possivel observar melhor a resposta

t = np.linspace(0, 0.1, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys1, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Foi escolhida a frequência angular de 100 rad/s, valor um pouco abaixo da banda de frequência ideal, o que permite vizualizar muito bem a atenuação do sinal na resposta a onda quadrada. Se fosse escolhida uma frequencia muito longe da banda do filtro, a amplitude da resposta seria muito menor que a entrada, e não seria possível vizualizar de forma comparativa a entrada e a saída.

# %% [markdown]
# # Circuito 2

# %%
#Foi escolhido uma frequência w de 200
w = 200

R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

#Função de transferência
sys2 = lti([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])


#Definição da variável tempo e da onda quadrada
t = np.linspace(0, 0.5, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys2, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# Ampliado é possivel observar melhor a resposta

t = np.linspace(0, 0.1, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys2, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# Foi escolhida a frequência angular de 200 rad/s, valor um pouco abaixo da banda de frequência ideal, o que permite vizualizar muito bem a atenuação do sinal na resposta a onda quadrada. Se fosse escolhida uma frequencia muito longe da banda do filtro, a amplitude da resposta seria muito menor que a entrada, e não seria possível vizualizar de forma comparativa a entrada e a saída.

# %% [markdown]
# # Circuito 3

# %%
#Foi escolhido uma frequência w de 30
w = 30

R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

#Função de transferência
sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])


#Definição da variável tempo e da onda quadrada
t = np.linspace(0, 0.5, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys3, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# A partir da estimativa da frequência de corte do sistema, na leitura do diagrama de Bode, foi escolhida uma frequência de w = 30 rad/s (frequência um pouco maior que a frequência de corte estimada pelo diagrama), a fim de gerar pouca atenuação no sinal de saída.
# Com isso, podemos ver que a resposta do sistema a onda quadrada evidencia um ganho negativo em relação a entrada.

# %% [markdown]
# # Circuito 4

# %%
#Foi escolhido uma frequência w de 50
w = 50

#Função de transferência
sys4 = lti([1], [1])


#Definição da variável tempo e da onda quadrada
t = np.linspace(0, 0.5, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys4, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 5

# %%
#Foi escolhido uma frequência w de 100
w = 100

R1 = 100
C2 = 5*(10**(-6))

#Função de transferência
sys5 = lti([-1], [C2*R1, 0])


#Definição da variável tempo e da onda quadrada
t = np.linspace(3, 3.2, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys5, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# A resposta será, novamente, a integral invertida da entrada, que nesse caso é uma onda quadrada.
#
# Esses picos de amplitude são gerados devido ao ganho do sistema e atenuação dos sinais de entrada.

# %% [markdown]
# # Circuito 6

# %%
#Foi escolhido uma frequência w de 100
w = 100

R = 100
C = 5*(10**(-6))

#Função de transferência
sys6 = lti([1], [R*C, 0])


#Definição da variável tempo e da onda quadrada
t = np.linspace(3, 3.2, 1000, endpoint=False)
u = signal.square(t*w)

tout, yout, xout = lsim(sys6, U=u, T=t)

plt.plot(t, u, 'r', alpha=0.5, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # (K) até (N) - Resposta aos n harmônicos da série de Fourier de uma onda quadrada de frequência $ω$

# %% [markdown]
# # Circuito 1

# %%
# Valores dos componentes
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

w = 100 # Frequência

t = np.linspace(0, 0.3, 1000, endpoint=False)
n=0

#Função de transferência
sys1 = signal.lti([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim(sys1, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim(sys1, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim(sys1, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim(sys1, U=input3, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input3, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# Quando se aplica em um passa-faixa uma frequência próxima da banda passante do circuito, percebe-se que a saída se assemelha ao sinal de entrada, mas com amplitudes menores, devido ao ganho relacionado à atenuação da entrada. \\
#
# Como esperado ao aplicar a série de Fourier, quanto maior o número de harmônicos, o sinal de saída tende a se igualar à onda quadrada.

# %% [markdown]
# # Circuito 2

# %%
# Valores dos Componentes
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

w = 200   # Frequência

t = np.linspace(0,0.1, 1000, endpoint=False)
n = 0

# Função de Transferência

sys2 = signal.lti ([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys2, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys2, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys2, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input4 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys2, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# Quando se aplica em um passa-faixa uma frequência próxima da banda passante do circuito, percebe-se que a saída se assemelha ao sinal de entrada, mas com amplitudes menores, devido ao ganho relacionado à atenuação da entrada. \\
#
# Como esperado ao aplicar a série de Fourier, quanto maior o número de harmônicos, o sinal de saída tende a se igualar à onda quadrada.

# %% [markdown]
# # Circuito 3

# %%
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

w = 30

t = np.linspace(0, 0.5, 1000, endpoint=False)
n=0

sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys3, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys3, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys3, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input4 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys3, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 4

# %%
w = 50

t = np.linspace(0, 0.5, 1000, endpoint=False)
n=0

sys4 = lti([1], [1])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys4, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys4, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys4, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input4 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys4, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 5

# %%
R1 = 100
C2 = 5*(10**(-6))

w = 100

t = np.linspace(0, 0.1, 1000, endpoint=False)
#t = np.linspace(3, 3.2, 1000, endpoint=False)
n=0

sys5 = lti([-1], [C2*R1, 0])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys5, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys5, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys5, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input4 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys5, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 6

# %%
R = 100
C = 5*(10**(-6))

w = 100

t = np.linspace(0, 0.1, 1000, endpoint=False)
n = 0

sys6 = lti([1], [R*C, 0])

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input1 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys6, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input2 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys6, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1.5, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input3 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys6, U=input3, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input3, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range (1, harmonico+1):
    serie = (np.sin(((2*num)-1)*t*w))/((2*num)-1)
    soma += serie
  input4 = soma * 4/(np.pi)
  tout, yout, xout = signal.lsim (sys6, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1.5, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # (O) - Resposta a uma Dente de Serra de frequência $ω$

# %% [markdown]
# # Circuito 1

# %%
# Valores dos componentes
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

#Foi escolhido uma frequência w de 100
w = 100

#Função de transferência
sys1 = lti([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])

#Definição da variável tempo e do sinal
t = np.linspace(0, 0.3, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys1, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 2

# %%
# Valores dos componentes
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1


#Foi escolhido uma frequência w de 200
w = 200 

#Função de transferência
sys2 = lti([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])

#Definição da variável tempo e do sinal
t = np.linspace(0, 0.16, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys2, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 3

# %%
# Valores dos componentes
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))


#Foi escolhido uma frequência w de 30
w = 30

#Função de transferência
sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])

#Definição da variável tempo e do sinal
t = np.linspace(0, 1, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys3, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 4

# %%
#Foi escolhido uma frequência w de 30
w = 30

#Função de transferência
sys4 = lti([1], [1])

#Definição da variável tempo e do sinal
t = np.linspace(0, 1, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys4, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 5

# %%
# Valores dos componentes
R1 = 100
C2 = 5*(10**(-6))

#Foi escolhido uma frequência w de 100
w = 100

#Função de transferência
sys5 = lti([-1], [C2*R1, 0])

#Definição da variável tempo e do sinal
t = np.linspace(0, 1, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys5, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

sys5 = lti([-1], [C2*R1, 0])
t = np.linspace(0, 100, 10000, endpoint=False)
u = signal.sawtooth(w*t)
tout, yout, xout = lsim(sys5, U=u, T=t)#
plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # Circuito 6

# %%
# Valores dos componentes
R = 100
C = 5*(10**(-6))

#Foi escolhido uma frequência w de 100
w = 100

#Função de transferência
sys6 = lti([1], [R*C, 0])

#Definição da variável tempo e do sinal
t = np.linspace(0, 1, 10000, endpoint=False)
u = signal.sawtooth(w*t)

tout, yout, xout = lsim(sys6, U=u, T=t)

plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()


t = np.linspace(0, 100, 10000, endpoint=False)
u = signal.sawtooth(w*t)
tout, yout, xout = lsim(sys6, U=u, T=t)
plt.plot(t, u, 'r', alpha=1, linewidth=1.5, label='Entrada')
plt.plot(tout, yout, 'k', linewidth=1.5, label='Saída')
plt.legend(loc='best', shadow=True, framealpha=1)
plt.grid(alpha=0.3)
plt.xlabel('t')
plt.show()

# %% [markdown]
# # (P) até (S) - Resposta aos n harmônicos da série de Fourier de uma onda quadrada de frequência $ω$

# %% [markdown]
# # Circuito 1

# %%
# Valores dos componentes
R1 = 10
R2 = 10
C1 = 0.001
L1 = 0.01

#Foi escolhido uma frequência w de 100
w = 100

#Função de transferência
sys1 = lti([1, 0], [R1*C1, ((R2 + R1)/R2), R1/L1])

t = np.linspace (0, 0.2, 1000, endpoint=False)
n=0

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input1 = 2*soma
  tout, yout, xout = signal.lsim(sys1, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys1, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys1, U=input2, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input4 = 2*soma
  tout, yout, xout = signal.lsim(sys1, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 2

# %%
# Valores dos componentes
R1 = 10
R2 = 100
C1 = 50*(10**(-6))
L1 = 0.1

#Foi escolhido uma frequência w de 200
w = 200

#Função de transferência
sys2 = lti([1, 0], [(L1/R1), ((R2 + R1)/R1), (1/(R1*C1))])

t = np.linspace (0, 0.16, 1000, endpoint=False)
n=0

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input1 = 2*soma
  tout, yout, xout = signal.lsim(sys2, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys2, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys2, U=input2, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input4 = 2*soma
  tout, yout, xout = signal.lsim(sys2, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 3

# %%
# Valores dos componentes
R1 = 1000
R2 = 10000
C1 = 3*(10**(-6))
C2 = 5*(10**(-6))

#Foi escolhido uma frequência w de 30
w = 30

#Função de transferência
sys3 = lti([1], [C1*C2*R1*R2, C2*(R2 + R1), 1])

t = np.linspace (0, 1, 1000, endpoint=False)
n=0

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input1 = 2*soma
  tout, yout, xout = signal.lsim(sys3, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys3, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys3, U=input2, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*t*w)))/num
    soma += serie
  input4 = 2*soma
  tout, yout, xout = signal.lsim(sys3, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 4

# %% [markdown]
# # Circuito 5

# %%
# Valores dos componentes
R1 = 100
C2 = 5*(10**(-6))

#Foi escolhido uma frequência w de 300
w = 300

#Função de transferência
sys5 = lti([-1], [C2*R1, 0])

#Definição da variável tempo e do sinal
t = np.linspace(0, 0.02, 10000, endpoint=False)
n=0

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input1 = 2*soma
  tout, yout, xout = signal.lsim(sys5, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys5, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys5, U=input2, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input4 = 2*soma
  tout, yout, xout = signal.lsim(sys5, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()

# %% [markdown]
# # Circuito 6

# %%
# Valores dos componentes
R = 100
C = 5*(10**(-6))

#Foi escolhido uma frequência w de 300
w = 300

#Função de transferência
sys6 = lti([1], [R*C, 0])

#Definição da variável tempo e do sinal
t = np.linspace(0, 0.02, 10000, endpoint=False)
n=0

fig, graph = plt.subplots(nrows=2, ncols=2, figsize=(18,12), sharex=False)

for harmonico in [1]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input1 = 2*soma
  tout, yout, xout = signal.lsim(sys6, U=input1, T=t)
  graph[0][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][0].plot(t, input1, alpha=0.5, linewidth=1, label='Entrada')
graph[0][0].legend(loc='best', shadow=True, framealpha=1)
graph[0][0].grid(alpha=0.3)
graph[0][0].set_xlabel('t')

for harmonico in [1, 2, 3]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys6, U=input2, T=t)
  graph[0][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[0][1].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[0][1].legend(loc='best', shadow=True, framealpha=1)
graph[0][1].grid(alpha=0.3)
graph[0][1].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input2 = 2*soma
  tout, yout, xout = signal.lsim(sys6, U=input2, T=t)
  graph[1][0].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][0].plot(t, input2, alpha=0.5, linewidth=1, label='Entrada')
graph[1][0].legend(loc='best', shadow=True, framealpha=1)
graph[1][0].grid(alpha=0.3)
graph[1][0].set_xlabel('t')

for harmonico in [1, 2, 3, 4, 5, 6, 7]:
  soma = 0
  for num in range(1, harmonico+1):
    serie = ((-1**(num))*(np.sin(num*np.pi*t*w)))/num
    soma += serie
  input4 = 2*soma
  tout, yout, xout = signal.lsim(sys6, U=input4, T=t)
  graph[1][1].plot(tout, yout, linewidth=1.5, label='Harmônico %1.0f'%(num))
  n+=1

graph[1][1].plot(t, input4, alpha=0.5, linewidth=1, label='Entrada')
graph[1][1].legend(loc='best', shadow=True, framealpha=1)
graph[1][1].grid(alpha=0.3)
graph[1][1].set_xlabel('t')

plt.show()
